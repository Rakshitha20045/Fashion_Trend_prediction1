# %%
import pandas as pd 
df = pd.read_csv("C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_DateS_Range-LAPTOP-98PL5KBA.csv")
df
# Out:
#                                 uniq_id crawl_timestamp  product_id  \
# 0      b511a3268e0fd7aa10a6d7728202aff1      2019-01-01     5965158
# 1      e0ea9e59f65f2cb82c1dd43c0d087b71      2019-01-01     2439641
# 2      e5d919fab7a0d4e976d442b5a24547aa      2019-01-01     2370037
# 3      cb1508097ed71472128cddbe569d6e22      2019-01-01     8456497
# 4      4cc45701da275bf75beeaae79e83e59d      2019-01-01     4679834
# ...                                 ...             ...         ...
# 14995  dbab7ceeeb415c3c986ee7a420e5e5be      2024-12-30     8888631
# 14996  f8822769bfab61f144a985c405ef09f4      2024-12-30     9948673
# 14997  83ddde3e2fcaa4b395daf7f90f37ef49      2024-12-30     7546862
# 14998  9851d584e428de709324faa6ebb5957e      2024-12-30     8076761
# 14999  c535d026143ef48aefc0a651925342ae      2024-12-31     8707293
#
#                                                     link          size  \
# 0      https://www.myntra.com/kurta-sets/deyann/deyan...             M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   uniq_id                   15000 non-null  object
#  1   crawl_timestamp           15000 non-null  object
#  2   product_id                15000 non-null  int64
#  3   link                      15000 non-null  object
#  4   size                      15000 non-null  object
#  5   variant_sku               15000 non-null  object
#  6   brand                     15000 non-null  object
#  7   care_instructions         14971 non-null  object
#  8   dominant_material         14436 non-null  object
#  9   title                     15000 non-null  object
#  10  actual_color              13982 non-null  object
#  11  dominant_color            13976 non-null  object
#  12  product_type              13580 non-null  object
# ...

# %%
df = df[['crawl_timestamp','variant_price']]
df
# Out:
#       crawl_timestamp  variant_price
# 0          2019-01-01           2396
# 1          2019-01-01            698
# 2          2019-01-01            719
# 3          2019-01-01            799
# 4          2019-01-01           2024
# ...               ...            ...
# 14995      2024-12-30           1709
# 14996      2024-12-30           1033
# 14997      2024-12-30           1499
# 14998      2024-12-30           1099
# 14999      2024-12-31            854
#
# [15000 rows x 2 columns]

# %%
df['crawl_timestamp']
# Out:
# 0        2019-01-01
# 1        2019-01-01
# 2        2019-01-01
# 3        2019-01-01
# 4        2019-01-01
#             ...
# 14995    2024-12-30
# 14996    2024-12-30
# 14997    2024-12-30
# 14998    2024-12-30
# 14999    2024-12-31
# Name: crawl_timestamp, Length: 15000, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2019-01-01 ')
datetime_object
# Out:
# datetime.datetime(2019, 1, 1, 0, 0)

# %%
df
# Out:
#       crawl_timestamp  variant_price
# 0          2019-01-01           2396
# 1          2019-01-01            698
# 2          2019-01-01            719
# 3          2019-01-01            799
# 4          2019-01-01           2024
# ...               ...            ...
# 14995      2024-12-30           1709
# 14996      2024-12-30           1033
# 14997      2024-12-30           1499
# 14998      2024-12-30           1099
# 14999      2024-12-31            854
#
# [15000 rows x 2 columns]

# %%
df['crawl_timestamp'] = df['crawl_timestamp'].apply(str_to_datetime)
df['crawl_timestamp']
# Out:
# C:\Users\RAKSHITHA\AppData\Local\Temp\ipykernel_18584\92062200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crawl_timestamp'] = df['crawl_timestamp'].apply(str_to_datetime)
# 0       2019-01-01
# 1       2019-01-01
# 2       2019-01-01
# 3       2019-01-01
# 4       2019-01-01
#            ...
# 14995   2024-12-30
# 14996   2024-12-30
# 14997   2024-12-30
# 14998   2024-12-30
# 14999   2024-12-31
# Name: crawl_timestamp, Length: 15000, dtype: datetime64[ns]

# %%
df.index = df.pop('crawl_timestamp')
df
# Out:
#                  variant_price
# crawl_timestamp
# 2019-01-01                2396
# 2019-01-01                 698
# 2019-01-01                 719
# 2019-01-01                 799
# 2019-01-01                2024
# ...                        ...
# 2024-12-30                1709
# 2024-12-30                1033
# 2024-12-30                1499
# 2024-12-30                1099
# 2024-12-31                 854
#
# [15000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['variant_price'])

# %%
def df_to_windowed_df(file_path, start_date_str, end_date_str, n=3):
    # Load CSV file
    df = pd.read_csv(file_path)
    
    # Convert date strings to datetime objects
    start_date = pd.to_datetime(start_date_str)
    end_date = pd.to_datetime(end_date_str)
    
    # Convert crawl_timestamp to datetime if needed
    if isinstance(df['crawl_timestamp'].iloc[0], str):
        df['crawl_timestamp'] = pd.to_datetime(df['crawl_timestamp'])
    
    # Filter dataframe between start_date and end_date
    df_subset = df[(df['crawl_timestamp'] >= start_date) & (df['crawl_timestamp'] <= end_date)]
    
    dates = []
    X, Y = [], []
    
    for i in range(len(df_subset) - n):
        # Extract window of size n + 1
        window = df_subset.iloc[i:i + n + 1]
        
        # Check if the window has exactly n + 1 rows
        if len(window) == n + 1:
            # Extract X (features) and Y (target)
            x = window['variant_price'].values[:-1]
            y = window['variant_price'].values[-1]
            
            # Append to lists
            dates.append(window['crawl_timestamp'].iloc[-1])
            X.append(x)
            Y.append(y)
    
    # Create DataFrame from lists
    ret_df = pd.DataFrame({'Target Date': dates})
    for i in range(n):
        ret_df[f'Target-{n-i}'] = [x[i] for x in X]
    ret_df['Target'] = Y
    
    return ret_df

# Example usage
file_path = 'C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_DateS_Range-LAPTOP-98PL5KBA.csv'
windowed_df = df_to_windowed_df(file_path, '2019-01-01', '2024-12-31', n=3)
print(windowed_df)
# Out:
#       Target Date  Target-3  Target-2  Target-1  Target
# 0      2019-01-01      2396       698       719     799
# 1      2019-01-01       698       719       799    2024
# 2      2019-01-01       719       799      2024    3374
# 3      2019-01-01       799      2024      3374    2239
# 4      2019-01-02      2024      3374      2239    1299
# ...           ...       ...       ...       ...     ...
# 14992  2024-12-30      1253      1619      2099    1709
# 14993  2024-12-30      1619      2099      1709    1033
# 14994  2024-12-30      2099      1709      1033    1499
# 14995  2024-12-30      1709      1033      1499    1099
# 14996  2024-12-31      1033      1499      1099     854
#
# [14997 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((14997,), (14997, 3, 1), (14997,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 3017691.5000 - mean_absolute_error: 1256.9313 - val_loss: 1484683.1250 - val_mean_absolute_error: 750.7712
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1322352.6250 - mean_absolute_error: 724.8506 - val_loss: 1460819.0000 - val_mean_absolute_error: 771.5913
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1301498.3750 - mean_absolute_error: 729.1263 - val_loss: 1475833.3750 - val_mean_absolute_error: 756.1285
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1219567.0000 - mean_absolute_error: 711.6979 - val_loss: 1465145.1250 - val_mean_absolute_error: 765.8318
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1285621.6250 - mean_absolute_error: 720.7147 - val_loss: 1466737.1250 - val_mean_absolute_error: 764.0949
# Epoch 6/100
# ...

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ...

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

# %%
# Plot with adjusted colors, styles, and alpha values
plt.plot(dates_train, train_predictions, linestyle='-', color='blue', alpha=0.9)
plt.plot(dates_train, y_train, linestyle='--', color='orange', alpha=0.9)
plt.plot(dates_val, val_predictions, linestyle='-', color='green', alpha=0.9)
plt.plot(dates_val, y_val, linestyle='--', color='red', alpha=0.9)
plt.plot(dates_test, test_predictions, linestyle='-', color='purple', alpha=0.9)
plt.plot(dates_test, y_test, linestyle='--', color='brown', alpha=0.9)
plt.plot(recursive_dates, recursive_predictions, linestyle='-', color='lightpink', alpha=0.9)

# Add legend
plt.legend(['Training Predictions', 'Training Observations',
            'Validation Predictions', 'Validation Observations',
            'Testing Predictions', 'Testing Observations',
            'Recursive Predictions'])

# %%
# Plot with markers, increased line width, and adjusted colors
plt.plot(dates_train, train_predictions, marker='o', markersize=5, linestyle='-', color='blue', linewidth=2)
plt.plot(dates_train, y_train, marker='s', markersize=5, linestyle='--', color='orange', linewidth=2)
plt.plot(dates_val, val_predictions, marker='^', markersize=5, linestyle='-', color='green', linewidth=2)
plt.plot(dates_val, y_val, marker='d', markersize=5, linestyle='--', color='red', linewidth=2)
plt.plot(dates_test, test_predictions, marker='v', markersize=5, linestyle='-', color='purple', linewidth=2)
plt.plot(dates_test, y_test, marker='x', markersize=5, linestyle='--', color='brown', linewidth=2)
plt.plot(recursive_dates, recursive_predictions, marker='p', markersize=5, linestyle='-', color='lightpink', linewidth=2)

# Add legend
plt.legend(['Training Predictions', 'Training Observations',
            'Validation Predictions', 'Validation Observations',
            'Testing Predictions', 'Testing Observations',
            'Recursive Predictions'], loc='best')

# Show plot
plt.show()

# %%
import pandas as pd

# Load your dataset
file_path = 'C:/Users/RAKSHITHA/OneDrive/Documents/MyntraDataset_sorted.csv'
df = pd.read_csv(file_path)

# Check the length of the existing DataFrame
df_length = len(df)

# Generate a continuous sequence of dates from 2019-01-01 to 2024-12-31
start_date = '2019-01-01'
end_date = '2024-12-31'
date_range = pd.date_range(start=start_date, end=end_date, periods=df_length)  # Generate same number of dates as rows in df

# Assign the continuous dates to the crawl_timestamp column
df['crawl_timestamp'] = date_range

# Save the modified DataFrame to a new CSV file
new_file_path = 'C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_Date_Range.csv'
df.to_csv(new_file_path, index=False)

print(f"Modified dataset saved to: {new_file_path}")
# Out:
# Modified dataset saved to: C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_Date_Range.csv

# %%
import pandas as pd

# Load your dataset
file_path = 'C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_Date_Range.csv'
df = pd.read_csv(file_path)

# Convert crawl_timestamp column to datetime format
df['crawl_timestamp'] = pd.to_datetime(df['crawl_timestamp'])

# Extract date part only (YYYY-MM-DD)
df['crawl_timestamp'] = df['crawl_timestamp'].dt.date

# Save the modified DataFrame to a new CSV file with only date format
new_file_path = 'C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_DateS_Range.csv'
df.to_csv(new_file_path, index=False)

print(f"Modified dataset saved to: {new_file_path}")
# Out:
# Modified dataset saved to: C:/Users/RAKSHITHA/OneDrive/Documents/Continuous_DateS_Range.csv

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have dates_train, X_train, y_train, X_val, y_val, X_test, y_test defined

# Define LSTM model
model = Sequential([
    LSTM(64, input_shape=(3, 1)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

# Train the LSTM model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

# Make predictions on training set for visualization
train_predictions = model.predict(X_train).flatten()

# Plotting training predictions and actual values
plt.figure(figsize=(14, 7))
plt.plot(dates_train, train_predictions, label='Training Predictions')
plt.plot(dates_train, y_train, label='Training Observations')
plt.legend()
plt.title('Training Set Predictions vs Observations')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\RAKSHITHA\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3109730.7500 - mean_absolute_error: 1336.2174 - val_loss: 3054466.0000 - val_mean_absolute_error: 1264.8911
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2508117.2500 - mean_absolute_error: 1069.3121 - val_loss: 2115359.0000 - val_mean_absolute_error: 850.2215
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1669707.0000 - mean_absolute_error: 710.1776 - val_loss: 1556274.7500 - val_mean_absolute_error: 734.4382
# Epoch 4/100
# ...

# %%
# Example of incorporating logical rules (pseudo-code)
def apply_seasonal_rule(date):
    # Example: Higher demand during holidays
    if date.month in [11, 12]:  # November or December
        return 1.2  # Increase in demand
    else:
        return 1.0  # No adjustment

# Apply seasonal rule to enhance predictions
def enhance_predictions(X):
    enhanced_X = np.zeros_like(X)
    for i in range(len(X)):
        enhanced_X[i] = X[i] * apply_seasonal_rule(dates_train[i])
    return enhanced_X

X_train_enhanced = enhance_predictions(X_train)
X_val_enhanced = enhance_predictions(X_val)
X_test_enhanced = enhance_predictions(X_test)

# Retrain the model with enhanced inputs
model_enhanced = Sequential([
    LSTM(64, input_shape=(3, 1)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_enhanced.compile(loss='mse', 
                       optimizer=Adam(learning_rate=0.001),
                       metrics=['mean_absolute_error'])

history_enhanced = model_enhanced.fit(X_train_enhanced, y_train, 
                                      validation_data=(X_val_enhanced, y_val), 
                                      epochs=100)

# Plotting enhanced predictions
train_predictions_enhanced = model_enhanced.predict(X_train_enhanced).flatten()

plt.figure(figsize=(14, 7))
plt.plot(dates_train, train_predictions_enhanced, label='Enhanced Training Predictions')
plt.plot(dates_train, y_train, label='Training Observations')
plt.legend()
plt.title('Enhanced Training Set Predictions vs Observations')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3212940.0000 - mean_absolute_error: 1343.0747 - val_loss: 3176362.7500 - val_mean_absolute_error: 1312.1913
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2462922.0000 - mean_absolute_error: 1122.4133 - val_loss: 2305690.0000 - val_mean_absolute_error: 933.9161
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1791344.7500 - mean_absolute_error: 764.7615 - val_loss: 1678127.2500 - val_mean_absolute_error: 733.6671
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1357142.0000 - mean_absolute_error: 656.7624 - val_loss: 1496021.3750 - val_mean_absolute_error: 746.1912
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1306008.2500 - mean_absolute_error: 689.7440 - val_loss: 1466295.1250 - val_mean_absolute_error: 764.5552
# Epoch 6/100
# ...

# %%
# Example of enhanced feature engineering and iterative approach
def enhance_predictions(X, dates):
    enhanced_X = np.zeros_like(X)
    for i in range(len(X)):
        date = dates[i]
        enhanced_X[i] = X[i] * apply_seasonal_rule(date)  # Enhance with seasonal rule
        # Additional feature engineering or rule-based adjustments
        
    return enhanced_X

# Apply enhanced feature engineering
X_train_enhanced = enhance_predictions(X_train, dates_train)
X_val_enhanced = enhance_predictions(X_val, dates_val)
X_test_enhanced = enhance_predictions(X_test, dates_test)

# Define and compile model
model_enhanced = Sequential([
    LSTM(64, input_shape=(3, 1)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_enhanced.compile(loss='mse', 
                       optimizer=Adam(learning_rate=0.001),
                       metrics=['mean_absolute_error'])

# Train model with enhanced inputs
history_enhanced = model_enhanced.fit(X_train_enhanced, y_train, 
                                      validation_data=(X_val_enhanced, y_val), 
                                      epochs=100)

# Evaluate and visualize performance
train_predictions_enhanced = model_enhanced.predict(X_train_enhanced).flatten()

plt.figure(figsize=(14, 7))
plt.plot(dates_train, train_predictions_enhanced, label='Enhanced Training Predictions')
plt.plot(dates_train, y_train, label='Training Observations')
plt.legend()
plt.title('Enhanced Training Set Predictions vs Observations')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# Epoch 1/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3150726.0000 - mean_absolute_error: 1349.3074 - val_loss: 3167764.5000 - val_mean_absolute_error: 1308.9109
# Epoch 2/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2477831.7500 - mean_absolute_error: 1114.0626 - val_loss: 2354036.0000 - val_mean_absolute_error: 956.3768
# Epoch 3/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1904200.3750 - mean_absolute_error: 785.3677 - val_loss: 1717574.3750 - val_mean_absolute_error: 738.1498
# Epoch 4/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1300631.0000 - mean_absolute_error: 647.9399 - val_loss: 1507206.0000 - val_mean_absolute_error: 742.7515
# Epoch 5/100
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1297179.6250 - mean_absolute_error: 695.3083 - val_loss: 1469523.6250 - val_mean_absolute_error: 761.3688
# Epoch 6/100
# ...

# %%
from sklearn.metrics import mean_squared_error

# Calculate MSE for training, validation, and test sets
train_mse = mean_squared_error(y_train, train_predictions_enhanced)
val_predictions_enhanced = model_enhanced.predict(X_val_enhanced).flatten()
val_mse = mean_squared_error(y_val, val_predictions_enhanced)
test_predictions_enhanced = model_enhanced.predict(X_test_enhanced).flatten()
test_mse = mean_squared_error(y_test, test_predictions_enhanced)

print(f"Train MSE: {train_mse}")
print(f"Validation MSE: {val_mse}")
print(f"Test MSE: {test_mse}")
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 1301638.75
# Validation MSE: 1466332.875
# Test MSE: 1257536.375

# %%
from sklearn.metrics import mean_absolute_error

# Calculate MAE for training, validation, and test sets
train_mae = mean_absolute_error(y_train, train_predictions_enhanced)
val_mae = mean_absolute_error(y_val, val_predictions_enhanced)
test_mae = mean_absolute_error(y_test, test_predictions_enhanced)

print(f"Train MAE: {train_mae}")
print(f"Validation MAE: {val_mae}")
print(f"Test MAE: {test_mae}")
# Out:
# Train MAE: 717.4684448242188
# Validation MAE: 764.5152587890625
# Test MAE: 714.177001953125

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate_model_performance(y_true, y_pred):
    # Calculate MSE, MAE, and R-squared
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    # Print the metrics
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"R-squared (R2): {r2}")
    
    # Return metrics as a dictionary if needed
    return {'mse': mse, 'mae': mae, 'r2': r2}

# Example usage:
# Assuming you have predictions for train, validation, and test sets: train_predictions_enhanced, val_predictions_enhanced, test_predictions_enhanced
print("Training Set Performance:")
evaluate_model_performance(y_train, train_predictions_enhanced)

print("\nValidation Set Performance:")
evaluate_model_performance(y_val, val_predictions_enhanced)

print("\nTest Set Performance:")
evaluate_model_performance(y_test, test_predictions_enhanced)
# Out:
# Training Set Performance:
# Mean Squared Error (MSE): 1301638.75
# Mean Absolute Error (MAE): 717.4684448242188
# R-squared (R2): -0.0001081228256225586
#
# Validation Set Performance:
# Mean Squared Error (MSE): 1466332.875
# Mean Absolute Error (MAE): 764.5152587890625
# R-squared (R2): -0.008123636245727539
#
# Test Set Performance:
# Mean Squared Error (MSE): 1257536.375
# Mean Absolute Error (MAE): 714.177001953125
# R-squared (R2): -0.0027015209197998047
# {'mse': 1257536.4, 'mae': 714.177, 'r2': -0.0027015209197998047}

# %%
# Define LSTM predictions (example values, replace with your actual predictions)
lstm_predictions = {
    'mse': 1257536.4,
    'mae': 714.177,
    'r2': -0.0027015209197998047
}

# Define CNN prediction (example value, replace with your actual prediction)
cnn_prediction = 0.6  # Example CNN prediction

# Combine predictions (using average for demonstration)
combined_mse = (lstm_predictions['mse'] + cnn_prediction) / 2
combined_mae = (lstm_predictions['mae'] + cnn_prediction) / 2
combined_r2 = (lstm_predictions['r2'] + cnn_prediction) / 2

# Print combined predictions
print(f"Combined MSE: {combined_mse}")
print(f"Combined MAE: {combined_mae}")
print(f"Combined R-squared: {combined_r2}")
# Out:
# Combined MSE: 628768.5
# Combined MAE: 357.3885
# Combined R-squared: 0.2986492395401001
